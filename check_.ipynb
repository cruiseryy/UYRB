# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Myriad Pro'
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

import numpy as np
from utils import *

# bin0 = np.loadtxt('binary.ref')
bin0 = np.loadtxt('re1.reference')[:,-4:]

# tru0 = np.loadtxt('true.ref')
tru0 = np.loadtxt('re0.reference')[:,-4:]

# %%
# fig, ax = plt.subplots(2, 2, figsize=(10, 10))
# xx = tru0
# yy = tru1

# for i in range(4):
#     ax[i//2, i%2].scatter(xx[:,i], yy[:,i], s=5)
#     ax[i//2, i%2].axline([np.min(xx[:,i]), np.min(xx[:,i])],[np.max(xx[:,i]), np.max(xx[:,i])] , color='r')
#     ax[i//2, i%2].set_xlabel('x')
#     ax[i//2, i%2].set_ylabel('y')
#     ax[i//2, i%2].set_title('obj {}'.format(i))
#     print(np.max(np.abs(xx[:,i] - yy[:,i]))/np.min(np.abs(xx[:,i])))

# %%
# fig, ax = plt.subplots(2, 2, figsize=(10, 10))
# xx = bin0
# yy = bin1

# for i in range(4):
#     ax[i//2, i%2].scatter(xx[:,i], yy[:,i], s=5)
#     ax[i//2, i%2].axline([np.min(xx[:,i]), np.min(xx[:,i])],[np.max(xx[:,i]), np.max(xx[:,i])] , color='r')
#     ax[i//2, i%2].set_xlabel('x')
#     ax[i//2, i%2].set_ylabel('y')
#     ax[i//2, i%2].set_title('obj {}'.format(i))
#     print(np.max(np.abs(xx[:,i] - yy[:,i]))/np.min(np.abs(xx[:,i])))

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
mins_bin = np.min(bin0, axis=0)
maxs_bin = np.max(bin0, axis=0)
mins_tru = np.min(tru0, axis=0)
maxs_tru = np.max(tru0, axis=0)
mins = np.minimum(mins_bin, mins_tru)
maxs = np.maximum(maxs_bin, maxs_tru)
xlabels = ['obj1', 'obj2', 'obj3', 'obj4']
precision = [0, 1 , 3, 2]
shading_tru = 0.0 * np.ones((tru0.shape[0], ))
shading_bin = 0.0 * np.ones((bin0.shape[0], ))

plotter = parallel_coords(mins, maxs, xlabels, precision)
plotter.plot_(ax, tru0, cmap = 'Reds_r', shading = shading_tru)
plotter.plot_(ax, bin0, cmap = 'Blues_r', shading = shading_bin)

# %%
his_obj0 = np.loadtxt('his_obj_dps0.csv')
his_obj1 = np.loadtxt('his_obj_dps1.csv')
his_baseline = np.loadtxt('his_obj_actual.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 his_obj0 = np.loadtxt('his_obj_dps0.csv')
#       2 his_obj1 = np.loadtxt('his_obj_dps1.csv')
#       3 his_baseline = np.loadtxt('his_obj_actual.csv')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# ...
